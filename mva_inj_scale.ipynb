# %%
import numpy as np
import os
from collections import Counter
import pandas as pd

# %%
mva_sgc70 =pd.read_fwf('mva_csg70_50pc_injscale.txt',index_col=0).drop('170817').drop('E264930').rename(index=str,columns={'MVA' : 'sgc70'})
mva_sgc100 =pd.read_fwf('mva_csg100_50pc_injscale.txt',index_col=0).drop('170817').drop('E264930').rename(index=str,columns={'MVA' : 'sgc100'})
mva_sgc150 =pd.read_fwf('mva_csg150_50pc_injscale.txt',index_col=0).drop('170817').drop('E264930').rename(index=str,columns={'MVA' : 'sgc150'})
mva_sgc300 =pd.read_fwf('mva_csg300_50pc_injscale.txt',index_col=0).drop('170817').drop('E264930').rename(index=str,columns={'MVA' : 'sgc300'})
mva_adia =pd.read_fwf('mva_adi-a_50pc_injscale.txt',index_col=0).drop('170817').drop('E264930').rename(index=str,columns={'MVA' : 'adi-a'})
mva_adib =pd.read_fwf('mva_adi-b_50pc_injscale.txt',index_col=0).drop('170817').drop('E264930').rename(index=str,columns={'MVA' : 'adi-b'})
mva_adic =pd.read_fwf('mva_adi-c_50pc_injscale.txt',index_col=0).drop('170817').drop('E264930').rename(index=str,columns={'MVA' : 'adi-c'})
mva_adid =pd.read_fwf('mva_adi-d_50pc_injscale.txt',index_col=0).drop('170817').drop('E264930').rename(index=str,columns={'MVA' : 'adi-d'})
mva_adie =pd.read_fwf('mva_adi-e_50pc_injscale.txt',index_col=0).drop('170817').drop('E264930').rename(index=str,columns={'MVA' : 'adi-e'})
mva_bns =pd.read_fwf('mva_bns_50pc_injscale.txt',index_col=0).drop('170817').drop('E264930').rename(index=str,columns={'MVA' : 'BNS'})
mva_nsbh =pd.read_fwf('mva_nsbh_50pc_injscale.txt',index_col=0).drop('170817').drop('E264930').rename(index=str,columns={'MVA' : 'NSBH'})

# %%
x_sgc70 =pd.read_fwf('x_sgc70q9_50pc_injscale.txt',index_col=0).drop('E264930').rename(index=str,columns={'X-pipeline' : 'sgc70'})
x_sgc100 =pd.read_fwf('x_sgc100q9_50pc_injscale.txt',index_col=0).drop('E264930').rename(index=str,columns={'X-pipeline' : 'sgc100'})
x_sgc150 =pd.read_fwf('x_csg150_50pc_injscale.txt',index_col=0).drop('E264930').rename(index=str,columns={'X-pipeline' : 'sgc150'})
x_sgc300 =pd.read_fwf('x_sgc300q9_50pc_injscale.txt',index_col=0).drop('E264930').rename(index=str,columns={'X-pipeline' : 'sgc300'})
x_adia =pd.read_fwf('x_adi-a_50pc_injscale.txt',index_col=0).drop('E264930').rename(index=str,columns={'X-pipeline' : 'adi-a'})
x_adib =pd.read_fwf('x_adi-b_50pc_injscale.txt',index_col=0).drop('E264930').rename(index=str,columns={'X-pipeline' : 'adi-b'})
x_adic =pd.read_fwf('x_adi-c_50pc_injscale.txt',index_col=0).drop('E264930').rename(index=str,columns={'X-pipeline' : 'adi-c'})
x_adid =pd.read_fwf('x_adi-d_50pc_injscale.txt',index_col=0).drop('E264930').rename(index=str,columns={'X-pipeline' : 'adi-d'})
x_adie =pd.read_fwf('x_adi-e_50pc_injscale.txt',index_col=0).drop('E264930').rename(index=str,columns={'X-pipeline' : 'adi-e'})
x_bns =pd.read_fwf('x_bns_50pc_injscale.txt',index_col=0).drop('E264930').rename(index=str,columns={'X-pipeline' : 'BNS'})
x_nsbh =pd.read_fwf('x_nsbh_50pc_injscale.txt',index_col=0).drop('E264930').rename(index=str,columns={'X-pipeline' : 'NSBH'})

# %%
mva_df = pd.concat([mva_sgc70, mva_sgc100, mva_sgc150, mva_sgc300, mva_adia,mva_adib,mva_adic,mva_adid,mva_adie,mva_bns,mva_nsbh],axis=1)

# %%
mva_df
# Out:
#             sgc70    sgc100    sgc150    sgc300     adi-a     adi-b     adi-c  \
# GRB
# E264842  1.142970  0.883083  0.778640  0.869987  0.256852  0.155476  0.180948
# E265282  1.364430  1.038110  0.947985  1.063390  0.320373  0.184820  0.234969
# E266096  1.398620  1.077920  0.919448  1.059390  0.307452  0.183057  0.239273
# E269364  1.165130  0.884798  0.815690  0.852577  0.268167  0.169098  0.193806
# E269496  1.278990  0.870484  0.803807  0.836966  0.262726  0.163698  0.188920
# E269667  1.098200  0.762746  0.608902  0.668647  0.210491  0.125479  0.163743
# E272290  0.825071  0.592528  0.550413  0.578680  0.180380  0.111448  0.130172
# E272325  0.842728  0.630704  0.551350  0.585757  0.179671  0.112380  0.129820
# E273104  0.649108  0.505574  0.424909  0.505516  0.152614  0.084455  0.114118
# E273131  1.119730  0.814525  0.723649  0.793544  0.234293  0.131297  0.172770
# E277236  1.334520  1.091840  0.874800  0.976754  0.282235  0.177895  0.217646
# E278027  1.129500  0.810404  0.706021  0.791744  0.238171  0.133333  0.172412
# E278188  0.724980  0.543152  0.494495  0.544458  0.166066  0.091232  0.118800
#
#             adi-d     adi-e       BNS      NSBH
# GRB
# E264842  0.519997  0.180419  0.262560  0.184407
# E265282  0.638168  0.237973  0.323777  0.231172
# E266096  0.625043  0.227030  0.316200  0.238354
# E269364  0.563374  0.193528  0.266917  0.195225
# E269496  0.558294  0.192290  0.265102  0.192251
# E269667  0.433962  0.151641  0.216228  0.159644
# E272290  0.370117  0.130170  0.180452  0.132461
# E272325  0.381544  0.134272  0.184205  0.136373
# E273104  0.302800  0.111663  0.151761  0.109110
# E273131  0.477770  0.179514  0.243469  0.174574
# E277236  0.630283  0.228135  0.294084  0.223018
# E278027  0.518350  0.175237  0.243904  0.177015
# E278188  0.334204  0.123294  0.166610  0.120240

# %%
x_df = pd.concat([x_sgc70, x_sgc100, x_sgc150, x_sgc300, x_adia,x_adib,x_adic,x_adid,x_adie,x_bns,x_nsbh],axis=1)

# %%
x_df
# Out:
#             sgc70    sgc100    sgc150    sgc300     adi-a     adi-b     adi-c  \
# GRB
# E264842  1.364230  0.965715  0.863607  0.942321  0.280687  0.168542  0.210344
# E265282  1.416750  1.111780  0.966496  1.069020  0.314272  0.188137  0.231074
# E266096  1.609400  1.111770  0.945129  1.056150  0.328834  0.188801  0.254813
# E269364  1.210480  0.927320  0.992146  0.844101  0.796595  0.166489  0.198907
# E269496  1.372420  0.889502  0.962586  0.830080  0.314951  0.160957  0.185878
# E269667  1.114210  0.730321  0.847344  0.650363  0.314711  0.123639  0.162875
# E272290  0.855965  0.582708  0.663644  0.579255  0.215062  0.111198  0.131886
# E272325  0.849713  0.641746  0.698378  0.607044  0.275547  0.112330  0.128546
# E273104  0.673236  0.485057  0.596182  0.476627  0.202874  0.084607  0.114449
# E273131  1.085200  0.812494  0.954253  0.812687  0.308376  0.132360  0.174497
# E277236  1.814800  1.406920  1.823330  1.335360  0.453559  0.205733  0.262548
# E278027  1.176600  0.801292  0.950267  0.787752  0.304938  0.135410  0.175219
# E278188  0.733388  0.548730  0.640816  0.538326  0.207630  0.091346  0.117971
#
#             adi-d     adi-e       BNS      NSBH
# GRB
# E264842  0.641454  0.203709  0.280687  0.204942
# E265282  0.642584  0.234318  0.328845  0.241813
# E266096  0.663747  0.235640  0.323121  0.246256
# E269364  0.573159  0.193885  0.268268  0.194688
# E269496  0.558370  0.195983  0.261531  0.190978
# E269667  0.451064  0.152043  0.202970  0.152071
# E272290  0.375618  0.129303  0.177434  0.128397
# E272325  0.386731  0.134914  0.184969  0.135551
# E273104  0.299567  0.113094  0.145102  0.104916
# E273131  0.489290  0.173624  0.245654  0.175868
# E277236  0.803864  0.258100  0.381372  0.288845
# E278027  0.510932  0.174373  0.243363  0.177597
# E278188  0.329548  0.123869  0.166709  0.119349

# %%
mva_df.median(axis=0)
# Out:
# sgc70     1.129500
# sgc100    0.814525
# sgc150    0.723649
# sgc300    0.793544
# adi-a     0.238171
# adi-b     0.133333
# adi-c     0.172770
# adi-d     0.518350
# adi-e     0.179514
# BNS       0.243904
# NSBH      0.177015
# dtype: float64

# %%
x_df.median(axis=0)
# Out:
# sgc70     1.176600
# sgc100    0.812494
# sgc150    0.945129
# sgc300    0.812687
# adi-a     0.308376
# adi-b     0.135410
# adi-c     0.175219
# adi-d     0.510932
# adi-e     0.174373
# BNS       0.245654
# NSBH      0.177597
# dtype: float64

# %%
plot = pd.concat([mva_df.median(axis=0),x_df.median(axis=0)],axis=1,keys=['MVA','X-pipeline']).plot(kind='bar',title='Median 50% Injection Scale Upper Limit')
fig = plot.get_figure()
