# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
day = np.array([1,10,11,16,17,18])
thing = np.array([48,34,26,17,17,13])

# %%
delta_day = day[-1]#-day[0]
delta_thing = thing[-1]-thing[0]

# %%
m=delta_thing/delta_day
days = np.arange(31)
y=m*days+48
m2 = -48./30.
y2 = m2*days+48

# %%
m
# Out:
# -1.9444444444444444

# %%
plt.plot(day,thing)
plt.plot(days+1,y,'--')
plt.plot(days+1,y2,'.')
plt.ylim(0,50)
plt.xlim(1,31)
plt.xlabel('Days')
plt.ylabel('Things left to do')
# Out:
# Text(0,0.5,'Things left to do')

# %%
np.argwhere(y<0)[0]
# Out:
# array([25])
