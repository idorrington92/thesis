# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
day = np.array([1,10,11,16,17])
thing = np.array([48,34,26,17,17])

# %%
delta_day = day[-1]#-day[0]
delta_thing = thing[-1]-thing[0]

# %%
m=delta_thing/delta_day
days = np.arange(31)
y=m*days+48

# %%
m
# Out:
# -1.8235294117647058

# %%
plt.plot(day,thing)
plt.plot(days+1,y,'--')
plt.ylim(0,50)
plt.xlim(1,31)
plt.xlabel('Days')
plt.ylabel('Things left to do')
# Out:
# Text(0,0.5,'Things left to do')
